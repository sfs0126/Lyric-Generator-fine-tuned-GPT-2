# %% [markdown]
# <a href="https://colab.research.google.com/github/sfs0126/Lyric-Generator-fine-tuned-GPT-2/blob/main/Model_Train_and_Evaluation_SS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lyric Generation for Different Music Genres
# ## Fine-Tuning GPT-2 and Evaluating with Perplexity
# ### Text Generation of Popular Music Lyrics
#
# ##### Model Training and Evaluation

# %%
# !pip install transformers

# %%
pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-yg8ljo6x
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-yg8ljo6x
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
# !pip install tensorboard

# %%
import os
import time
import datetime
from google.colab import drive

import torch
from torch.utils.data import Dataset, DataLoader, random_split, RandomSampler, SequentialSampler
torch.manual_seed(42)

from transformers import GPT2LMHeadModel,  GPT2Tokenizer, GPT2Config, GPT2LMHeadModel
from transformers import AdamW, get_linear_schedule_with_warmup

import pandas as pd
from sklearn.model_selection import train_test_split
import re

# %%
gpu_info = !nvidia-smi -L
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
    print("Not connected to a GPU")
else:
    print(gpu_info)
# Out:
# Not connected to a GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install datasets

# %% [markdown]
# ### Training Rock Model

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/rock_model_finetuned'\
  --model_type=gpt2 \
  --model_name_or_path='/content/drive/MyDrive/Topics in Computing Notebooks/models/rock_model' \
  --do_train \
  --train_file='/content/drive/MyDrive/Data/rock_train.txt'\
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/rock_valid.txt'\
  --per_device_train_batch_size=2 \
  --per_device_eval_batch_size=2 \
  --learning_rate 5e-5 \
  --num_train_epochs=5

# %% [markdown]
# ### Rock Model Evaluations

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/rock_model_finetuned_eval'\
  --model_type=gpt2 \
  --model_name_or_path='/content/drive/MyDrive/Topics in Computing Notebooks/models/rock_model_finetuned' \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/rock_test.txt' \
  --per_device_eval_batch_size=2 \

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/rock_model_gpt2_eval'\
  --model_type=gpt2 \
  --model_name_or_path=gpt2 \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/rock_test.txt' \
  --per_device_eval_batch_size=2 \

# %% [markdown]
# ### Training Pop Model

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/pop_model_finetuned_cpu'\
  --model_type=gpt2 \
  --model_name_or_path=gpt2 \
  --do_train \
  --train_file='/content/drive/MyDrive/Data/pop_train.txt'\
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/pop_valid.txt'\
  --per_device_train_batch_size=2 \
  --per_device_eval_batch_size=2 \
  --learning_rate 5e-5 \
  --num_train_epochs=5
# Out:
# 12/07/2021 20:37:46 - WARNING - __main__ - Process rank: -1, device: cpu, n_gpu: 0distributed training: False, 16-bits training: False
# 12/07/2021 20:37:46 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=0,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %% [markdown]
# ### Pop Model Evaluations

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/pop_model_finetuned_eval'\
  --model_type=gpt2 \
  --model_name_or_path='/content/drive/MyDrive/Topics in Computing Notebooks/models/pop_model_finetuned' \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/pop_test.txt' \
  --per_device_eval_batch_size=2 \

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/pop_model_gpt2_eval'\
  --model_type=gpt2 \
  --model_name_or_path=gpt2 \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/pop_test.txt' \
  --per_device_eval_batch_size=2 \

# %% [markdown]
# ### Training Hiphop Model

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/hiphop_model_finetuned'\
  --model_type=gpt2 \
  --model_name_or_path=gpt2 \
  --do_train \
  --train_file='/content/drive/MyDrive/Data/hiphop_train.txt'\
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/hiphop_valid.txt'\
  --per_device_train_batch_size=2 \
  --per_device_eval_batch_size=2 \
  --learning_rate 5e-5 \
  --num_train_epochs=5
# Out:
# 12/07/2021 17:48:15 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/07/2021 17:48:15 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %% [markdown]
# ### Hiphop Model Evaluations

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/hiphop_model_finetuned_eval'\
  --model_type=gpt2 \
  --model_name_or_path='/content/drive/MyDrive/Topics in Computing Notebooks/models/hiphop_model_finetuned' \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/hiphop_test.txt' \
  --per_device_eval_batch_size=2 \
# Out:
# 12/07/2021 18:13:33 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/07/2021 18:13:33 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
# !python '/content/drive/MyDrive/Topics in Computing Notebooks/run_clm.py' \
  --output_dir='/content/drive/MyDrive/Topics in Computing Notebooks/models/hiphop_model_gpt2_eval'\
  --model_type=gpt2 \
  --model_name_or_path=gpt2 \
  --do_eval \
  --validation_file='/content/drive/MyDrive/Data/hiphop_test.txt' \
  --per_device_eval_batch_size=2 \
# Out:
# 12/07/2021 18:15:19 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/07/2021 18:15:19 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
# Launch tensorboard
#%load_ext tensorboard
#%tensorboard --logdir logs
